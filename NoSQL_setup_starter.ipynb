# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'local', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
sample_document = db.establishments.find_one()
pprint(sample_document)
# Out:
# {'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pines Calyx',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4587.362402580997,
#  'FHRSID': 254250,
#  'LocalAuthorityBusinessID': 'PI/000066174',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DZ',
#  'RatingDate': '2021-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64beba11d5c8a9ddd97935b8'),
#  'geocode': {'latitude': '51.148133', 'longitude': '1.383298'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254250',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
insert_result = establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('64beba46d4e35ab03cb8098d'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_type_query = {"BusinessType": "Restaurant/Cafe/Canteen"}
business_type_projection = {"BusinessTypeID", "BusinessType"}
business_type_result = establishments.find_one(business_type_query, business_type_projection)
pprint(business_type_result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64beba11d5c8a9ddd97935b9')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
correct_business_type_id = business_type_result["BusinessTypeID"]
establishments.update_one(new_restaurant, {"$set": {"BusinessTypeID": correct_business_type_id}})

# %%
# Confirm that the new restaurant was updated
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('64beba46d4e35ab03cb8098d'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = establishments.count_documents({"LocalAuthorityName": "Dover"})
print(f"Number of documents with LocalAuthorityName 'Dover': {dover_count}")
# Out:
# Number of documents with LocalAuthorityName 'Dover': 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete_result = establishments.delete_many({"LocalAuthorityName": "Dover"})
print(f"{delete_result.deleted_count} documents deleted")
# Out:
# 994 documents deleted

# %%
# Check if any remaining documents include Dover
remaining_dover_count = establishments.count_documents({"LocalAuthorityName": "Dover"})
print(f"Number of documents with LocalAuthorityName 'Dover' after deletion: {remaining_dover_count}")
# Out:
# Number of documents with LocalAuthorityName 'Dover' after deletion: 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('64beba11d5c8a9ddd979389b'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, {"$set": {"geocode.longitude": {"$toDouble": "$geocode.longitude"}, "geocode.latitude": {"$toDouble": "$geocode.latitude"}}})

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, {"$set": {"RatingValue": {"$toInt": "$RatingValue"}}})

# %%
# Check that the coordinates are now numbers
#[doc for doc in establishments.find({}, ['geocode.longitude', 'geocode.latitude'])]
list(establishments.find({}, ["geocode.longitude"]))
# Out:
# [{'_id': ObjectId('64beba11d5c8a9ddd979389b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979389f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a3'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a4'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a5'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a6'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a8'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938a9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938aa'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ab'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ac'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ad'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ae'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938af'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b0'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b1'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b3'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b4'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b5'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b6'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b8'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938b9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ba'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938bb'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938bc'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938bd'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938be'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938bf'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c0'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c1'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c3'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c4'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c5'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c6'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c8'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938c9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ca'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938cb'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938cd'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ce'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d0'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d1'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d3'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d5'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938d9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938da'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938db'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938dc'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938dd'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938de'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938df'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e0'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e1'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e4'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e8'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938e9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ea'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938eb'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ec'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ed'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ee'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f0'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f1'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f2'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f3'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f4'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f5'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f6'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f7'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f8'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938f9'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938fa'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938fb'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938fc'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938fd'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938fe'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd97938ff'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793900'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793901'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793902'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793903'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793904'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793905'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793906'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793907'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793908'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793909'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979390f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793910'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793911'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793912'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793913'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793914'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793915'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793916'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793917'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793918'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793919'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979391f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793920'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793921'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793922'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793923'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793924'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793925'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793926'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793927'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793928'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793929'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979392f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793930'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793931'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793932'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793933'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793935'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793936'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793937'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793938'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793939'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979393f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793940'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793941'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793942'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793943'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793944'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793945'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793946'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793947'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793949'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979394b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979394c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979394d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979394e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979394f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793950'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793951'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793952'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793953'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793954'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793955'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793957'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793958'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793959'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979395f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793960'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793961'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793963'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793964'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793965'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793966'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793967'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793968'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793969'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979396f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793970'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793971'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793972'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793973'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793974'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793975'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793976'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793977'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793978'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793979'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979397f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793980'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793981'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793982'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793983'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793984'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793985'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793986'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793987'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793988'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793989'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398a'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398b'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398c'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398d'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398e'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd979398f'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793990'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793991'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793992'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793993'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793994'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9793995'),
#   'geocode': {'longitude': {'$toDouble': '$geocode.longitude'}}},
#  {'_id': ObjectId('64beba11d5c8a9ddd9